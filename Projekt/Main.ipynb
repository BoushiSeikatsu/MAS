# %%
import pandas as pd
import DataProcessing as pr

# %%
dfNodes = pd.read_csv("E:/Python Scripts/MAS/Projekt/fb-pages-company.nodes", sep=',')

# %%
dfNodes
# Out:
#                     id                           name  new_id
# 0      290994417624733                 ALDI Australia   11192
# 1           5510619796                       Wetpaint   10743
# 2         254509578109                    Q102.7 KBIQ   13087
# 3      322744631148014  Paraná TV, Bom Dia PR e G1 PR   12630
# 4         175046706411                        easyJet    7453
# ...                ...                            ...     ...
# 14108     123895198258                      Hay House    5367
# 14109  199585676751778                    Sunday Kiss   12638
# 14110  395075817267899               American Express    8695
# 14111     243173360004                 New York Style     159
# 14112      10431579593                     UrbanCincy    3729
#
# [14113 rows x 3 columns]

# %%
dfEdges = pd.read_csv("E:/Python Scripts/MAS/Projekt/fb-pages-company.edges", sep=',')

# %%
dfEdges
# Out:
#        node_1  node_2
# 0           0    2243
# 1           0   12084
# 2           0    6169
# 3           0    4887
# 4           0    3694
# ...       ...     ...
# 52305   10331   10331
# 52306   14056   14056
# 52307   14060   14074
# 52308   14064   14087
# 52309   14092   14092
#
# [52310 rows x 2 columns]

# %%
#adjacencyMatrix = pr.getAdjacencyMatrix(dfEdges)
#Vezmu levý prvek přidám do jeho klíče pravý prvek a pak se kouknu jestli v klíči pravého prvku je levý prvek
adjacencyList = pr.getAdjacencyList(dfEdges)
print(adjacencyList)
# Out:
# {0: [2243, 12084, 6169, 4887, 3694, 6260, 6977, 8788, 2399, 1362], 2243: [0, 1362, 2243, 3694, 6977, 2399], 12084: [0, 353, 486, 1231, 1606, 1644, 2091, 2182, 11992, 2399, 2628, 2863, 12239, 5666, 3694, 3733, 4428, 11453, 5748, 5784, 14043, 6716, 6977, 7207, 7413, 8204, 7946, 8007, 8126, 9428, 9869, 5201, 11327, 11877, 12072, 12611, 14099, 12680], 6169: [0, 2399, 3694, 6977], 4887: [0], 3694: [0, 856, 1362, 2243, 2399, 2506, 10676, 9893, 4119, 6203, 6169, 7903, 6260, 6977, 8306, 12084, 5885, 13749, 4702], 6260: [0, 1362, 2399, 3694, 6977], 6977: [0, 856, 1362, 2224, 2226, 2243, 2399, 2506, 3694, 4119, 6169, 6260, 8788, 9078, 12084, 8324, 13749, 3665], 8788: [0, 6411, 3483, 8533, 6977], 2399: [0, 1362, 2243, 8435, 12084, 6169, 2506, 6260, 3694, 6977, 3665], 1362: [0, 1051, 4920, 2243, 3694, 6260, 6977, 5953, 2399, 5885, 12825, 3665, 11207], 1: [10168, 5913, 1731, 5459, 3562, 8575, 12886, 7558, 3482, 7573, 4619, 7044], 10168: [1, 175, 495, 1731, 2443, 3482, 3562, 3707, 5459, 7970, 7172
# ...

# %%
print(f"Počet vrcholů: {len(dfNodes)}")
print(f"Počet hran: {len(dfEdges)}")
# Out:
# Počet vrcholů: 14113
# Počet hran: 52310
